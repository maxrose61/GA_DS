# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


#import plotly.plotly as py
#py.sign_in('maxrose', '••••••••••')
#import cufflinks as cf
#cf.set_config_file(offline=False, world_readable=True, theme='ggplot')

df = pd.read_table('stonesbeatles_raw01.csv', encoding= 'utf-8',header=0)
df.sort_values(['artist', 'date_year','releasename'], axis=0, inplace=True)
plt.rcParams['figure.figsize'] = 8, 6

#df.head()
df.groupby('artist').hist()
# Out:
# artist
# The Beatles           [[Axes(0.125,0.684722;0.336957x0.215278), Axes...
# The Rolling Stones    [[Axes(0.125,0.684722;0.336957x0.215278), Axes...
# dtype: object

# %%
#df.boxplot(column='a', by='b')

df.describe()
# Out:
#             trackid   recordingid  release_group     date_year            id
# count  1.941000e+04  1.941000e+04   1.941000e+04  18606.000000  1.941000e+04
# mean   1.175803e+07  6.100857e+06   4.438711e+05   1998.289477  3.887040e+06
# std    5.937519e+06  6.027095e+06   5.126509e+05     10.751466  4.486459e+06
# min    1.036500e+04  1.524300e+04   2.717000e+03   1963.000000  3.631000e+03
# 25%    9.740836e+06  2.940410e+05   3.974100e+04           NaN  2.249090e+05
# 50%    1.223124e+07  4.506737e+06   1.285400e+05           NaN  6.747570e+05
# 75%    1.583793e+07  1.252020e+07   8.408480e+05           NaN  7.025700e+06
# max    2.076346e+07  1.888645e+07   1.660824e+06   2015.000000  1.295406e+07
